# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
Leff_ew="/home2/grand/data/detector/Light_GP300Antenna_EWarm_leff.npz"

# %%
Leff=np.load("/home2/grand/data/detector/Light_GP300Antenna_EWarm_leff.npz")

# %%
#def inspect_npz_file(file_path):
#    try:
#        npz_file = np.load(file_path)
#        print("Contents of the .npz file:")
#        for item in npz_file.items():
#            print(f" - {item[0]}: {item[1]}")
#    except Exception as e:
#        print(f"Error opening or inspecting .npz file: {e}")
#
## Replace 'file_path' with the path to your .npz file
#file_path = "/home2/grand/data/detector/Light_GP300Antenna_EWarm_leff.npz"
#inspect_npz_file(file_path)

# %%
import numpy as np

# Load the .npz file
npz_file = np.load(Leff_ew)

# Access the arrays by their keys and save them as separate NumPy arrays
for key in npz_file.keys():
    np.save(f'{key}.npy', npz_file[key])
    print(f"Saved array '{key}' as '{key}.npy'")

print("Arrays saved successfully.")
# Out:
# Saved array 'version' as 'version.npy'
# Saved array 'freq_mhz' as 'freq_mhz.npy'
# Saved array 'leff_theta' as 'leff_theta.npy'
# Saved array 'leff_phi' as 'leff_phi.npy'
# Arrays saved successfully.

# %%
freq=np.load('freq_mhz.npy')
leff_theta=np.load('leff_theta.npy')

# %%
leff_theta.shape
# Out:
# (361, 91, 221)

# %%
leff_theta[0,0,:]
# Out:
# array([-2.07625766e-04-0.00067495j, -7.13105546e-05-0.00065818j,
#         7.99129921e-05-0.00066152j,  2.43092203e-04-0.00068766j,
#         4.14823589e-04-0.00073884j,  5.91326971e-04-0.00081679j,
#         7.68518541e-04-0.00092263j,  9.42110317e-04-0.00105688j,
#         1.10769866e-03-0.00121938j,  1.26086490e-03-0.0014093j ,
#         1.39728899e-03-0.00162513j,  1.51281478e-03-0.00186467j,
#         1.60359615e-03-0.00212508j,  1.66616461e-03-0.00240288j,
#         1.69755286e-03-0.00269404j,  1.69537112e-03-0.00299401j,
#         1.65790436e-03-0.00329782j,  1.58417411e-03-0.0036002j ,
#         1.47397735e-03-0.00389567j,  1.32795156e-03-0.00417866j,
#         1.14757067e-03-0.00444361j,  9.35153046e-04-0.00468513j,
#         6.93867565e-04-0.00489811j,  4.27655323e-04-0.00507776j,
#         1.41263285e-04-0.00521994j, -1.59908333e-04-0.00532098j,
#        -4.69801977e-04-0.00537805j, -7.81816430e-04-0.00538911j,
# ...

# %%
plt.plot(freq,abs(leff_theta[0,0,:]))
plt.plot(freq,abs(leff_theta[0,10,:]))
plt.plot(freq,abs(leff_theta[0,20,:]))
plt.plot(freq,abs(leff_theta[0,30,:]))
plt.plot(freq,abs(leff_theta[0,40,:]))
plt.plot(freq,abs(leff_theta[0,50,:]))
plt.plot(freq,abs(leff_theta[0,60,:]))
plt.plot(freq,abs(leff_theta[0,70,:]))
plt.plot(freq,abs(leff_theta[0,80,:]))
plt.plot(freq,abs(leff_theta[0,90,:]))
