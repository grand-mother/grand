# %%
from grand.dataio.root_files import get_handling3dtraces
# Out:
# Welcome to JupyROOT 6.26/10

# %%
fadc= "/home/jcolley/projet/grand_wk/data/root/dc2/ZHAireS/sim_Xiaodushan_20221025_220000_RUN0_CD_ZHAireS_0000/adc_29-24992_L1_0000.root"
adc3d = get_handling3dtraces(fadc,10)

# %%
adc3d.plot_footprint_val_max()

# %%
adc3d.remove_trace_low_signal(2)
# Out:
# array([], dtype=int64)

# %%
adc3d.plot_footprint_val_max()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 adc3d.plot_footprint_val_max()
#
# File ~/projet/grand_wk/grandlib/grand/grand/basis/traces_event.py:570, in Handling3dTraces.plot_footprint_val_max(self)
#     568 def plot_footprint_val_max(self):  # pragma: no cover
#     569     """Plot footprint max value"""
# --> 570     self.network.plot_footprint_1d(
#     571         self.get_max_norm(), f"Max ||{self.type_trace}||", self, unit=self.unit_trace
#     572     )
#
# File ~/projet/grand_wk/grandlib/grand/grand/basis/du_network.py:185, in DetectorUnitNetwork.plot_footprint_1d(self, a_values, title, traces, scale, unit)
#     182         plt.draw()
#     184 fig, ax1 = plt.subplots(1, 1)
# --> 185 s_title = f"{title}\n{self.get_nb_du()} DUs; Surface {int(self.get_surface())} km$^2$"
#     186 s_title += f"; Name site: {self.name}"
# ...
